# %% [markdown]
# # 02 Web Scraping
#
# Scrape a supplemental table (any reliable SpaceX page with tabular details).
# - Use `requests` and `BeautifulSoup`
# - Parse an HTML table and save to `../data/scraped_table.csv`
