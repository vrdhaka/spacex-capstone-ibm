# %% [markdown]
# # 01 Spacex Api
#
# Use the SpaceX REST API to pull launch data.
# - Endpoint (example): https://api.spacexdata.com/v4/launches (document in a markdown cell)
# - Normalize JSON with `pandas.json_normalize`
# - Save to `../data/launches_raw.csv`
# - Commit and push to GitHub.
