# %% [markdown]
# # 06 Folium Map
#
# Create Folium maps:
# - All sites as markers
# - Outcome color layers
# - (Optional) Proximity overlays
# Save HTML to `../maps/` and add screenshots to the PPTX
