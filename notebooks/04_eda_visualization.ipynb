# %% [markdown]
# # 04 Eda Visualization
#
# Create plots:
# - Flight Number vs. Launch Site (scatter)
# - Payload vs. Launch Site (scatter)
# - Success Rate vs. Orbit Type (bar)
# - Yearly average success (line)
# Save screenshots under `../maps/` or add to the PPTX
