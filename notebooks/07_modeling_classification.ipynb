# %% [markdown]
# # 07 Modeling Classification
#
# Build baseline classifiers:
# - Split data, train LR/RF/SVM
# - Compare accuracy; plot confusion matrix for best model
# - Save plots to `../maps/` and paste into PPTX
