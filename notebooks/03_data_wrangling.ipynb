# %% [markdown]
# # 03 Data Wrangling
#
# Load `launches_raw.csv` and `scraped_table.csv`.
# - Clean types, handle missing values
# - Feature engineer payload bins, orbit labels, success indicators
# - Merge and save `../data/cleaned_launches.csv`
